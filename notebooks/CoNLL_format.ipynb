# %% [markdown]
# #### CoNLL Format.
# ##### Task-2

# %%
import pandas as pd
import sys
script_dir=r'E:\2017.Study\Tenx\Week-5\W5.EthioMart-\scripts'
sys.path.append(script_dir)
filepath = r'E:\2017.Study\Tenx\Week-5\W5.EthioMart-\telegram_data_cleaned.csv'
df = pd.read_csv(filepath) 
df.head()
from CoNLL_processing import CoNLLFormatter

# %%
co_nll_formatter = CoNLLFormatter()
labeled_messages = co_nll_formatter.process_messages(df['Cleaned_Message'].head(50))
print(labeled_messages)
#co_nll_formatter.save_to_txt(labeled_messages, 'labeled_messages.txt')
# Out:
# የህፃናት B-PRODUCT
# መመገቢያ I-PRODUCT
# ጡጦ I-PRODUCT
# ዋጋ B-PRICE
# 400 I-PRICE
# ብር I-PRICE
# ውስን O
# ፍሬ O
# ነው O
# ያለው O
# አድራሻ O
# ቁ1መገናኛ B-LOC
# መሰረት I-LOC
# ደፋር I-LOC
# ሞል I-LOC
# ሁለተኛ O
# ፎቅ I-LOC
# ቢሮ I-LOC
# ቁ O
# 0506 B-PRICE
# ቁ2ፒያሳ B-LOC
# ጊዮርጊስ I-LOC
# አደባባይ I-LOC
# ራመት_ታቦር_ኦዳ_ህንፃ I-LOC
# 1ኛ O
# ፎቅ I-LOC
# ሱቅ I-LOC
# ቁ O
# 1 B-PRICE
# 107 I-PRICE
# 0902660722 I-PRICE
# 0928460606 I-PRICE
# ፒያሳ B-LOC
# ቅርንጫፍ O
# 0941337070 B-PRICE
# በ O
# ለማዘዝ O
# ይጠቀሙ O
# ለተጨማሪ O
# ማብራሪያ O
# የቴሌግራም B-LOC
# ገፃችን O
#
# የህፃናት B-PRODUCT
# መመገቢያ I-PRODUCT
# ጡጦ I-PRODUCT
# ዋጋ B-PRICE
# 400 I-PRICE
# ብር I-PRICE
# ውስን O
# ፍሬ O
# ነው O
# ያለው O
# አድራሻ O
# ቁ1መገናኛ B-LOC
# መሰረት I-LOC
# ደፋር I-LOC
# ሞል I-LOC
# ሁለተኛ O
# ፎቅ I-LOC
# ቢሮ I-LOC
# ቁ O
# 0506 B-PRICE
# ቁ2ፒያሳ B-LOC
# ጊዮርጊስ I-LOC
# አደባባይ I-LOC
# ራመት_ታቦር_ኦዳ_ህንፃ I-LOC
# 1ኛ O
# ፎቅ I-LOC
# ሱቅ I-LOC
# ቁ O
# 1 B-PRICE
# 107 I-PRICE
# 0902660722 I-PRICE
# 0928460606 I-PRICE
# ፒያሳ B-LOC
# ቅርንጫፍ O
# 0941337070 B-PRICE
# በ O
# ለማዘዝ O
# ይጠቀሙ O
# ለተጨማሪ O
# ...
